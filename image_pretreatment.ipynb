# %%
from __future__ import print_function

import time
from PIL import Image
import numpy as np

# %%
height = 512
width = 512

content_image_path = 'Cate.jpg'
content_image = Image.open(content_image_path)
content_image = content_image.resize((height, width))
print(type(content_image))
content_image
# Out:
# <class 'PIL.Image.Image'>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x1B8D4C56588>

# %%
style_image_path = 'Blanchett.jpg'
style_image = Image.open(style_image_path)
style_image = style_image.resize((height, width))
style_image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x1B8D3BD8860>

# %%
content_array = np.asarray(content_image, dtype='float32')
print(type(content_array))
print(content_array.shape)
content_array = np.expand_dims(content_array, axis=0)
print(type(content_array))
print(content_array.shape)

style_array = np.asarray(style_image, dtype='float32')
style_array = np.expand_dims(style_array, axis=0)
print(style_array.shape)
# Out:
# <class 'numpy.ndarray'>
# (512, 512, 3)
# <class 'numpy.ndarray'>
# (1, 512, 512, 3)
# (1, 512, 512, 3)

# %%
content_array[:,1,0]
# Out:
# array([[ 194.,  196.,  183.]], dtype=float32)
